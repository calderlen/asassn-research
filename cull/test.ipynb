# %%
import pandas as pd

# path to your CSV
csv_file = "asassn_x_vsx_matches_20250919_2252.csv"

# load
df = pd.read_csv(csv_file, low_memory=False)

# get unique classes (dropping NaN)
unique_classes = df["class"].dropna().unique()

# sort them for readability
unique_classes = sorted(unique_classes)

print("Unique class values:")
for c in unique_classes:
    print(c)
# Out:
# Unique class values:
# *
# ACEP:
# ACEPS:
# ACV:
# ACYG:
# AM:
# BCEP:
# BE
# BE:
# BY:
# CEP:
# CST
# CST:
# CTTS/DIP
# CV
# CV:
# CW:
# CWA:
# CWB:
# DCEP-FO:
# DCEP-FU:
# DCEP:
# DCEPS:
# DIP
# DIP:
# DPV/EA
# DPV/EB
# DPV/ELL
# DQ:
# DSCT:
# DSCT:+VAR
# DSCTC:
# DSCTr
# DYPer
# E-DO:
# E/DS
# E/DW
# E/KE
# E/KE:
# E/KW
# E/KW:
# E/RS
# E/RS:
# E/SD
# E/SD:
# E:
# E:/GS:
# E:/RS
# EA/AR
# EA/AR:
# EA/BD
# EA/D
# EA/D:
# EA/DM
# EA/DM:
# EA/DS
# EA/DS:
# EA/EL
# EA/EL+PUL
# EA/GS
# EA/GS:
# EA/HW
# EA/KE
# EA/KE:
# EA/KW
# EA/PN
# EA/RS
# EA/RS:
# EA/SD
# EA/SD:
# EA/WD
# EA/WR
# EA:
# EA:/RS
# EB/AR
# EB/D
# EB/DM
# EB/DM:
# EB/DW
# EB/GS
# EB/GS:
# EB/K
# EB/KE
# EB/KE:
# EB/KW
# EB/KW:
# EB/RS
# EB/SD
# EB/SD:
# EB/WR
# EB:
# EB:/GS:
# EB:/KE
# EB:/KE:
# EB:/RS
# EB:/SD
# EC:
# ED:
# ELL/PN
# ELL/RS/BY
# ELL:
# ELL:+ZAND:
# EP:
# ESD:
# EW/D:
# EW/DM:
# EW/DW
# EW/K
# EW/KE
# EW/KE:
# EW/KW
# EW/KW:
# EW/RS
# EW:
# EW:/KE
# EW:/KE:
# EW:/KW:
# EW:/RS
# EXOR/ROT
# FF:
# FKCOM:
# FSCMa
# FSCMa:
# FUOR:
# GCAS:
# GCAS:+E:
# GDOR:
# Galaxy
# HADS:
# HB:
# HB:+VAR
# HMXB
# HMXB+LERI:
# HMXB/XP
# HMXB:+GCAS:
# I:
# IA:
# IB:
# IBWD:
# IN:
# INA:
# INB:
# INS:
# INSB(YY)
# INSB:
# INST(YY)
# INT(YY)
# INT:
# IS:
# IS:|E:
# ISA:
# ISB:
# L:
# LB:
# LC:
# LERI:
# LMXB
# LMXB:
# LPV:
# M:
# MISC
# Microlens
# Microlens:
# Minor planet
# NC:
# NL/VY:
# NL:
# NON-CV
# PPN:
# PULS:
# PVTELIII:
# R/PN
# R:
# RCB:
# ROT/DIP
# ROT/WD
# ROT:
# RR:
# RRAB/BL
# RRAB/BL:
# RRAB:
# RRC/BL
# RRC/BL:
# RRC:
# RS:
# RV:
# RVA:
# RVB:
# S
# S:
# SDOR
# SDOR:
# SPB:
# SR:
# SRA:
# SRA:|CWA:
# SRB:
# SRC:
# SRD:
# SRS:
# SXARI:
# TTS/ROT/DIP
# TTS/ROT:
# TTS:
# UG/DQ
# UG/DQ+VY
# UG:
# UGSS/DQ:
# UGSU/IBWD
# UGZ/DQ:
# UGZ/IW:
# UGZ:
# UV:
# UXOR
# UXOR/ROT
# UXOR:
# VAR
# VAR:
# WR
# WR:
# WTTS/ROT:
# YSO/DIP
# YSO:
# ZAND
# ZAND+ELL:
# ZAND+NC:
# ZAND:
# ZZ:
# ZZLep
# ZZO:
# cPNB[e]
# roAm
# roAp
